# %% [markdown]
# ## Setup

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ## TidyCensus Example
#
# This notebook grabs data from the US Census using the [tidycensus package in R](https://walker-data.com/tidycensus/index.html). Make sure you have installed the `tidyverse` and `tidycensus` packages.

# %%
# %%R
#
# library(tidycensus)
# library(tidyverse)
#
# # store any shapefiles we grab from the census in ~/Library/Caches/tigris
# # in case the government removes the shapefiles FTP server again 😭
# options(tigris_use_cache = TRUE)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# ### Step 1 \| Get a Census API key
#
# Get a Census API key [here](https://api.census.gov/data/key_signup.html).
#
# Then make a new file called `.env` in this folder and put it in there.
#
# The `.env` file should look like this:
#
# ```bash
# CENSUS_API_KEY="your-api-key-here"
# ```
#
# This is what is known as an environment variable. We load it below in Python

# %%
from dotenv import load_dotenv
load_dotenv() # <- searches for a file named .env and loads the environment variables in it
# Out:
# False

# %%
# %%R
# # passes the CENSUS_API_KEY environment variable we loaded
# # in Python above to R (specifically to the tidycensus package)
# census_api_key(Sys.getenv("CENSUS_API_KEY"))
# Out:
# To install your API key for use in future sessions, run this function with `install = TRUE`.

# %% [markdown]
# ### Step 2 \| Figure out what tables you want data from and at what geographic granularity
#
# Use <https://censusreporter.org/> to figure out which tables you want.
#
# -   Scroll to the bottom of the page to see the tables.
# -   If you already know the table ID, stick that in the "Explore" section to learn more about that table.
#
# Once you've found the variable or variables you want, you can plug them into this code under `variables`.

# %%
# %%R
#
# # the variable B01003_001 was selectd from the census table
# # for population, which we found in censusreporter here:
# # https://censusreporter.org/tables/B01003/
#
#
# # Here are the various geographies you can use with tidycensus
# # https://walker-data.com/tidycensus/articles/basic-usage.html#geography-in-tidycensus
#
# # Get variable from ACS
# nyc_census_data <- get_acs(geography = "tract",
#                       state='NY',
#                       county = c("New York", "Kings", "Queens", "Bronx", "Richmond"),
#                       variables = c(
#                         population="B01003_001",
#                         total_units = "B25001_001",
#                         med_inc="B19013_001"
#                       ),
#                       year = 2024,
#                       survey="acs5",
#                       geometry=T)
#
# nyc_census_data
# Out:
# Simple feature collection with 6981 features and 5 fields (with 9 geometries empty)
# Geometry type: MULTIPOLYGON
# Dimension:     XY
# Bounding box:  xmin: -74.25563 ymin: 40.4961 xmax: -73.70036 ymax: 40.91771
# Geodetic CRS:  NAD83
# First 10 features:
#          GEOID                                        NAME    variable estimate
# 1  36005037600    Census Tract 376; Bronx County; New York  population     2115
# 2  36005037600    Census Tract 376; Bronx County; New York     med_inc    60288
# 3  36005037600    Census Tract 376; Bronx County; New York total_units      808
# 4  36005023502 Census Tract 235.02; Bronx County; New York  population     4490
# 5  36005023502 Census Tract 235.02; Bronx County; New York     med_inc    41780
# 6  36005023502 Census Tract 235.02; Bronx County; New York total_units     1734
# 7  36005006400     Census Tract 64; Bronx County; New York  population     4194
# 8  36005006400     Census Tract 64; Bronx County; New York     med_inc    41429
# 9  36005006400     Census Tract 64; Bronx County; New York total_units     1662
# 10 36005039100    Census Tract 391; Bronx County; New York  population     6071
#      moe                       geometry
# 1    292 MULTIPOLYGON (((-73.87038 4...
# 2  11556 MULTIPOLYGON (((-73.87038 4...
# 3    103 MULTIPOLYGON (((-73.87038 4...
# 4    988 MULTIPOLYGON (((-73.906 40....
# 5  24061 MULTIPOLYGON (((-73.906 40....
# 6    166 MULTIPOLYGON (((-73.906 40....
# 7    609 MULTIPOLYGON (((-73.87395 4...
# 8   9661 MULTIPOLYGON (((-73.87395 4...
# 9    199 MULTIPOLYGON (((-73.87395 4...
# 10  1238 MULTIPOLYGON (((-73.89003 4...
# Getting data from the 2020-2024 5-year ACS
# Using FIPS code '36' for state 'NY'
# Using FIPS code '061' for 'New York County'
# Using FIPS code '047' for 'Kings County'
# Using FIPS code '081' for 'Queens County'
# Using FIPS code '005' for 'Bronx County'
# Using FIPS code '085' for 'Richmond County'

# %% [markdown]
# ### Step 3 | Pivot to Wide Format
#
# Pivot from long to wide using `pivot_wider`.
#
# Depending on what you're trying to do, you may want the data in long or wide format. This example pivots the data to wide format, which will help us with mapping later on in the notebook.

# %%
# %%R
#
# nyc_census_data <- nyc_census_data |>
#   pivot_wider(
#     names_from=variable,
#     values_from = c(estimate, moe),
#     names_glue = "{variable}_{.value}"
#   )# pivot from wide to long
#
# nyc_census_data
# Out:
# Simple feature collection with 2327 features and 8 fields (with 3 geometries empty)
# Geometry type: MULTIPOLYGON
# Dimension:     XY
# Bounding box:  xmin: -74.25563 ymin: 40.4961 xmax: -73.70036 ymax: 40.91771
# Geodetic CRS:  NAD83
# # A tibble: 2,327 × 9
#    GEOID    NAME                   geometry population_estimate med_inc_estimate
#    <chr>    <chr>        <MULTIPOLYGON [°]>               <dbl>            <dbl>
#  1 3600503… Cens… (((-73.87038 40.87329, -…                2115            60288
#  2 3600502… Cens… (((-73.906 40.84939, -73…                4490            41780
#  3 3600500… Cens… (((-73.87395 40.83424, -…                4194            41429
#  4 3600503… Cens… (((-73.89003 40.85422, -…                6071            34663
#  5 3600503… Cens… (((-73.86627 40.87733, -…                5023            48073
#  6 3600500… Cens… (((-73.89705 40.8168, -7…                2949            35914
#  7 3600502… Cens… (((-73.86982 40.85548, -…                2433            53398
#  8 3600503… Cens… (((-73.85928 40.87773, -…                2964            83125
#  9 3600502… Cens… (((-73.91408 40.84528, -…                4942            37828
# 10 3600501… Cens… (((-73.92426 40.83068, -…                7738            45661
# # ℹ 2,317 more rows
# # ℹ 4 more variables: total_units_estimate <dbl>, population_moe <dbl>,
# #   med_inc_moe <dbl>, total_units_moe <dbl>
# # ℹ Use `print(n = ...)` to see more rows

# %% [markdown]
# ### Step 4 | Do calculations with `mutate`
#
# In R, you can use `mutate` to create new columns or modify existing ones.
#
# In this example, we create a column called `borough` by extracting the borough from the `NAME` column.
#
# _(hint, I used GitHub Copilot -- a tool similar to ChatGPT -- to do this...see my prompt in the comments)_

# %%
# %%R
#
# # Extract borough name from NAME by splitting strings like "Census Tract 147; Queens County; New York"
# # on semicolons and extracting the second element
# # Note: 2024 ACS data uses semicolons instead of commas as separators
#
# nyc_census_data <- nyc_census_data |>
#     mutate(
#         borough = str_split(NAME, ";") |> map_chr(2) |> str_trim(),
#         units_per_person = total_units_estimate / population_estimate
#     )
#
# nyc_census_data
# Out:
# Simple feature collection with 2327 features and 10 fields (with 3 geometries empty)
# Geometry type: MULTIPOLYGON
# Dimension:     XY
# Bounding box:  xmin: -74.25563 ymin: 40.4961 xmax: -73.70036 ymax: 40.91771
# Geodetic CRS:  NAD83
# # A tibble: 2,327 × 11
#    GEOID    NAME                   geometry population_estimate med_inc_estimate
#  * <chr>    <chr>        <MULTIPOLYGON [°]>               <dbl>            <dbl>
#  1 3600503… Cens… (((-73.87038 40.87329, -…                2115            60288
#  2 3600502… Cens… (((-73.906 40.84939, -73…                4490            41780
#  3 3600500… Cens… (((-73.87395 40.83424, -…                4194            41429
#  4 3600503… Cens… (((-73.89003 40.85422, -…                6071            34663
#  5 3600503… Cens… (((-73.86627 40.87733, -…                5023            48073
#  6 3600500… Cens… (((-73.89705 40.8168, -7…                2949            35914
#  7 3600502… Cens… (((-73.86982 40.85548, -…                2433            53398
#  8 3600503… Cens… (((-73.85928 40.87773, -…                2964            83125
#  9 3600502… Cens… (((-73.91408 40.84528, -…                4942            37828
# 10 3600501… Cens… (((-73.92426 40.83068, -…                7738            45661
# # ℹ 2,317 more rows
# # ℹ 6 more variables: total_units_estimate <dbl>, population_moe <dbl>,
# #   med_inc_moe <dbl>, total_units_moe <dbl>, borough <chr>,
# #   units_per_person <dbl>
# # ℹ Use `print(n = ...)` to see more rows

# %% [markdown]
# ### Step 5 | Example Plots
#
# Let's practice with histograms

# %%
# %%R -w 1000
#
# ggplot(nyc_census_data) +
#     aes(x=units_per_person) +
#     geom_histogram() +
#     facet_wrap(~borough)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: Removed 84 rows containing non-finite outside the scale range (`stat_bin()`).

# %%
# %%R -w 1000 -h 600
#
# ggplot(nyc_census_data) +
#     aes(x=units_per_person, y=borough) +
#     geom_jitter(alpha=0.5) +
#     # overlay a box and whisker plot that is transparent with no outliers and is red
#     geom_boxplot(fill=NA, outlier.shape=NA, color="red")
# Out:
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1: Removed 84 rows containing non-finite outside the scale range
# (`stat_boxplot()`).
#
# R[write to console]: 2: Removed 82 rows containing missing values or values outside the scale range
# (`geom_point()`).

# %% [markdown]
# ### Step 6 \| Example Map
#
# See more details about making maps here:
#
# https://walker-data.com/tidycensus/articles/spatial-data.html

# %%
# %%R
#
# library(tigris)
#
# # remove water from the shapefiles
# # https://walker-data.com/tidycensus/articles/spatial-data.html
# nyc_census_data <- nyc_census_data |>
#     erase_water()
# Out:
# To enable caching of data, set `options(tigris_use_cache = TRUE)`
# in your R script or .Rprofile.
# Fetching area water data for your dataset's location...
# Erasing water area...
# If this is slow, try a larger area threshold value.

# %%
# %%R -w 1000 -h 1000
#
# nyc_census_data |>
#   ggplot(aes(fill = units_per_person)) +
#   geom_sf(color = NA) +
#   scale_fill_gradient(low="white", high="red") +
#   theme_minimal() +
#   labs(
#     title = "There is a part of NYC where there are more housing units than people",
#     subtitle = "What's up with that?",
#     caption = "Source: US Census Bureau"
#   ) +
#   theme(
#     #make title and subitle bigger
#     plot.title = element_text(size = 20),
#     plot.subtitle = element_text(size = 15),
#     # move legend to top
#     legend.position = "top"
#   )
